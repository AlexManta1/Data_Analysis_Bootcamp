# %%
#Assessment - Data cleaning with Pandas

# %%
#Please import the file provided and answer the following questions:
#    1. How many songs are in the data set?
#    2. Which song was in the highest number of spotify playlists (in spotify playlists)?
#    3. What is the most common key songs are played on?
#    4. On average, do songs played in Major mode have a higher danceability than songs played in minor mode?

# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/alexandermanta/Downloads/spotify_playlist_data.csv')

# %%
#1. How many songs are in the data set?

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 860 entries, 0 to 859
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   track_name            860 non-null    object
#  1   artist(s)_name        856 non-null    object
#  2   artist_count          860 non-null    int64
#  3   released_year         859 non-null    float64
#  4   released_month        860 non-null    int64
#  5   released_day          860 non-null    int64
#  6   in_spotify_playlists  860 non-null    int64
#  7   in_spotify_charts     860 non-null    int64
#  8   streams               860 non-null    object
#  9   in_apple_playlists    860 non-null    int64
#  10  in_apple_charts       860 non-null    int64
#  11  in_deezer_playlists   860 non-null    object
#  12  in_deezer_charts      860 non-null    int64
#  13  in_shazam_charts      819 non-null    object
#  14  bpm                   860 non-null    int64
# ...

# %%
#2. Which song was in the highest number of spotify playlists (in spotify playlists)?

df.sort_values(by = 'in_spotify_playlists').iloc[-1,0]
# Out:
# 'Get Lucky - Radio Edit'

# %%
#3. What is the most common key songs are played on?

df.key.describe()
# Out:
# count     858
# unique     11
# top        C#
# freq      119
# Name: key, dtype: object

# %%
#4. On average, do songs played in Major mode have a higher danceability than songs played in minor mode?

df.sort_values(by='danceability_%').iloc[-1,16]
# Out:
# 'Minor'

# %%
#Make a copy of your data

# %%
df_clean = df.copy()

# %%
#Inspect you data
df_clean.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0         2023.0               7            14                   553
# 1         2023.0               3            23                  1474
# 2         2023.0               6            30                  1397
# 3         2019.0               8            23                  7858
# 4         2023.0               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# ...

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 860 entries, 0 to 859
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   track_name            860 non-null    object
#  1   artist(s)_name        856 non-null    object
#  2   artist_count          860 non-null    int64
#  3   released_year         859 non-null    float64
#  4   released_month        860 non-null    int64
#  5   released_day          860 non-null    int64
#  6   in_spotify_playlists  860 non-null    int64
#  7   in_spotify_charts     860 non-null    int64
#  8   streams               860 non-null    object
#  9   in_apple_playlists    860 non-null    int64
#  10  in_apple_charts       860 non-null    int64
#  11  in_deezer_playlists   860 non-null    object
#  12  in_deezer_charts      860 non-null    int64
#  13  in_shazam_charts      819 non-null    object
#  14  bpm                   860 non-null    int64
# ...

# %%
#Streams is object
#Year is float
#Missing values

# %%
#Check for duplicates

#Duplicated on the dataframe
df.duplicated().sum()
# Out:
# 2

# %%
df_clean[df_clean.duplicated(keep=False, subset = ['artist(s)_name'])]
# Out:
#                     track_name    artist(s)_name  artist_count  released_year  \
# 2                      vampire    Olivia Rodrigo             1         2023.0
# 3                 Cruel Summer      Taylor Swift             1         2019.0
# 4               WHERE SHE GOES         Bad Bunny             1         2023.0
# 7                     Columbia           Quevedo             1         2023.0
# 11                   Super Shy          NewJeans             1         2023.0
# ..                         ...               ...           ...            ...
# 852            BackOutsideBoyz             Drake             1         2022.0
# 853                 Broke Boys  Drake, 21 Savage             2         2022.0
# 854              The Great War      Taylor Swift             1         2022.0
# 856  Bigger Than The Whole Sky      Taylor Swift             1         2022.0
# 859                      Alone         Burna Boy             1         2022.0
#
# ...

# %%
#Getting rid of dupplicates

df_clean.drop_duplicates(inplace = True)

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 858 entries, 0 to 859
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   track_name            858 non-null    object
#  1   artist(s)_name        854 non-null    object
#  2   artist_count          858 non-null    int64
#  3   released_year         857 non-null    float64
#  4   released_month        858 non-null    int64
#  5   released_day          858 non-null    int64
#  6   in_spotify_playlists  858 non-null    int64
#  7   in_spotify_charts     858 non-null    int64
#  8   streams               858 non-null    object
#  9   in_apple_playlists    858 non-null    int64
#  10  in_apple_charts       858 non-null    int64
#  11  in_deezer_playlists   858 non-null    object
#  12  in_deezer_charts      858 non-null    int64
#  13  in_shazam_charts      817 non-null    object
#  14  bpm                   858 non-null    int64
# ...

# %%
#Give all column names
df_clean.columns
# Out:
# Index(['track_name', 'artist(s)_name', 'artist_count', 'released_year',
#        'released_month', 'released_day', 'in_spotify_playlists',
#        'in_spotify_charts', 'streams', 'in_apple_playlists', 'in_apple_charts',
#        'in_deezer_playlists', 'in_deezer_charts', 'in_shazam_charts', 'bpm',
#        'key', 'mode', 'danceability_%', 'valence_%', 'energy_%',
#        'acousticness_%', 'instrumentalness_%', 'liveness_%', 'speechiness_%'],
#       dtype='object')

# %%
df_clean.drop(columns = ['in_shazam_charts','instrumentalness_%','energy_%'], inplace = True)

# %%
df_clean.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0         2023.0               7            14                   553
# 1         2023.0               3            23                  1474
# 2         2023.0               6            30                  1397
# 3         2019.0               8            23                  7858
# 4         2023.0               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  ...  in_deezer_playlists  \
# ...

# %%
df_clean.drop(['valence_%','speechiness_%'], axis =1, inplace = True)

# %%
df_clean.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0         2023.0               7            14                   553
# 1         2023.0               3            23                  1474
# 2         2023.0               6            30                  1397
# 3         2019.0               8            23                  7858
# 4         2023.0               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  in_apple_charts  \
# ...
